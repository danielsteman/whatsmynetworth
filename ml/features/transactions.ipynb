# %%
import os
import sys

sys.path.append(os.path.dirname(os.getcwd()))

# %%
from app.core.config import settings

# %%
from sqlalchemy import create_engine, inspect
from sqlalchemy.orm import Session

engine = create_engine(settings.database_url)
session = Session(engine)
table_names = inspect(engine).get_table_names()

table_names
# Out:
# ['accounts',
#  '_prisma_migrations',
#  'alembic_version',
#  'VerificationRequest',
#  'User',
#  'Account',
#  'Session',
#  'customers',
#  'connections',
#  'transaction_metadata',
#  'transactions']

# %%
import pandas as pd

df = pd.read_sql("SELECT * FROM transactions", engine)
df
# Out:
#                        id  duplicated    mode  status     made_on     amount  \
# 0     1368566952791906711       False  normal  posted  2024-07-20    6000.00
# 1     1368566952791906712       False  normal  posted  2024-07-20  175000.00
# 2     1368566952791906713       False  normal  posted  2024-07-20   17861.59
# 3     1368566952800295322       False  normal  posted  2024-07-20  173660.71
# 4     1368566952800295323       False  normal  posted  2024-07-20    -234.06
# ...                   ...         ...     ...     ...         ...        ...
# 1195  1368567111428872832       False  normal  posted  2024-09-17    -211.44
# 1196  1368567111437261441       False  normal  posted  2024-09-17  -86736.00
# 1197  1368567111437261442       False  normal  posted  2024-09-17      -2.75
# 1198  1368567111437261443       False  normal  posted  2024-09-17     -57.47
# 1199  1368567111437261444       False  normal  posted  2024-09-17       1.00
#
#      currency_code            description             category extra_id  \
# 0              EUR          Business ST A             pharmacy    33240
# 1              EUR                    N/A  bills_and_utilities    33239
# 2              EUR         FE018654297473     home_improvement    33238
# 3              EUR                    N/A  bills_and_utilities    33237
# 4              EUR     RABO BANK SCHIPHOL             transfer    33236
# ...            ...                    ...                  ...      ...
# 1195           EUR  ATM 888 AEROPORT  BLR             transfer    34415
# 1196           EUR    BAI Handel New York    business_services    34414
# 1197           EUR  Albert Plus 1454 Stad            groceries    34413
# 1198           EUR     BV Zakelijke Markt  bills_and_utilities    34412
# 1199           EUR          Rabobank WB A             pharmacy    34411
#
#                account_id            created_at            updated_at
# 0     1368566952515082646  2024-09-18T18:44:30Z  2024-09-18T18:44:30Z
# 1     1368566952515082646  2024-09-18T18:44:30Z  2024-09-18T18:44:30Z
# 2     1368566952515082646  2024-09-18T18:44:30Z  2024-09-18T18:44:30Z
# 3     1368566952515082646  2024-09-18T18:44:30Z  2024-09-18T18:44:30Z
# 4     1368566952515082646  2024-09-18T18:44:30Z  2024-09-18T18:44:30Z
# ...                   ...                   ...                   ...
# 1195  1368566952515082646  2024-09-18T18:44:49Z  2024-09-18T18:44:49Z
# 1196  1368566952515082646  2024-09-18T18:44:49Z  2024-09-18T18:44:49Z
# 1197  1368566952515082646  2024-09-18T18:44:49Z  2024-09-18T18:44:49Z
# 1198  1368566952515082646  2024-09-18T18:44:49Z  2024-09-18T18:44:49Z
# 1199  1368566952515082646  2024-09-18T18:44:49Z  2024-09-18T18:44:49Z
#
# [1200 rows x 13 columns]
